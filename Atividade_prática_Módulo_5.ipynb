# %%
print('Boas vindas a calculadora de operações simples! 🧮')

while True:
  # Recebendo dois nunumeros do usuario
  valor1 = float(input('Digite o primeiro valor: '))
  valor2 = float(input('Digite o segundo valor: '))

  print('Escolha a operação desejada: ')

  # Realizando ao menos quatro operações matemáticas
  print('1 - Somar.')
  print('2 - Subtrair.')
  print('3 - Multiplicar.')
  print('4 - Dividir.')
  print('5 - Média.')
  print('6 - Resto.')
  print('7 - Sair.')

  opcao = input('Digite a opção desejada')

  # Usando condicional
  if opcao == '1':
    resultado = valor1 + valor2
    print('O resultado é igual a: ', resultado)

  elif opcao == '2':
          resultado = valor1 - valor2
          print('O resultado é igual a: ', resultado)

  elif opcao == '3':
     resultado = valor1*valor2
     print('O resultado é igual a: ', resultado)

  elif opcao == '4':
    if valor2 == 0:
      print('Não é possível dividir por zero! ⚠️')
    else:
            resultado = valor1/valor2
            print('O resultado é igual a: ', resultado)

  elif opcao == '5':
    resultado = (valor1 + valor2)/2
    print('O resultado é igual a: ', resultado)

  elif opcao == '6':
            resultado = valor1%valor2
            print('O resultado é igual a: ', resultado)

  elif opcao == '7':
            print( 'Até a próxima! 🌼')
            break
# Out:
# Boas vindas a calculadora de operações simples! 🧮
# Escolha a operação desejada:
# 1 - Somar.
# 2 - Subtrair.
# 3 - Multiplicar.
# 4 - Dividir.
# 5 - Média.
# 6 - Resto.
# 7 - Sair.
# O resultado é igual a:  13.0
# Escolha a operação desejada:
# 1 - Somar.
# 2 - Subtrair.
# 3 - Multiplicar.
# 4 - Dividir.
# 5 - Média.
# 6 - Resto.
# 7 - Sair.
# O resultado é igual a:  0.0
# Escolha a operação desejada:
# 1 - Somar.
# 2 - Subtrair.
# 3 - Multiplicar.
# 4 - Dividir.
# 5 - Média.
# 6 - Resto.
# 7 - Sair.
# O resultado é igual a:  25.0
# Escolha a operação desejada:
# 1 - Somar.
# 2 - Subtrair.
# 3 - Multiplicar.
# 4 - Dividir.
# 5 - Média.
# 6 - Resto.
# 7 - Sair.
# O resultado é igual a:  1.0
# Escolha a operação desejada:
# 1 - Somar.
# 2 - Subtrair.
# 3 - Multiplicar.
# 4 - Dividir.
# 5 - Média.
# 6 - Resto.
# 7 - Sair.
# Não é possível dividir por zero! ⚠️
# Escolha a operação desejada:
# 1 - Somar.
# 2 - Subtrair.
# 3 - Multiplicar.
# 4 - Dividir.
# 5 - Média.
# 6 - Resto.
# ...
